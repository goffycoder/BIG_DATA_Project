# %% [markdown]
# ## Area in SQ KM

# %%
area_per_year_sq_km = area_per_year*0.01  #converting HEctors into sqaure km

pd.set_option('display.float_format',lambda x: '%.2f' % x )
print(area_per_year_sq_km)
# Out:
# Year
# 1997   1821983.50
# 1998   1681843.38
# 1999   1651576.41
# 2000   1654069.23
# 2001   1648366.48
# 2002   1550840.49
# 2003   1701810.52
# 2004   1679842.73
# 2005   1689412.14
# 2006   1729734.82
# 2007   1738328.77
# 2008   1729355.43
# 2009   1695322.73
# 2010   1830774.02
# 2011   1776475.92
# 2012   1812969.50
# 2013   1825012.97
# 2014   1772932.47
# 2015   1794882.17
# 2016   1849138.53
# 2017   1860464.74
# 2018   1851698.06
# 2019   1949792.20
# Name: Area(HEC), dtype: float64

# %% [markdown]
# # Visualization

# %%
years = np.array(area_per_year_sq_km.index)
areas = np.array(area_per_year_sq_km.values)

# %% [markdown]
# ## Line chart

# %%
plt.figure(figsize=(14, 7))
plt.plot(area_per_year_sq_km.index, area_per_year_sq_km, marker='o', linestyle='-', color='blue')
plt.title('Year-wise Area under Cultivation (Square Kilometers)')
plt.xlabel('Year')
plt.ylabel('Area (Square Kilometers)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar chart

# %%
import plotly.express as px

year_on_year_change_df = year_on_year_change.reset_index()

fig = px.bar(
    year_on_year_change_df, 
    x='Year', 
    y='Area(HEC)',  
    title='Year-on-Year Change in Area under Cultivation (Square Kilometers)',
    labels={'Area(HEC)': 'Change in Area (Square Kilometers)'}, 
    text='Area(HEC)'  
)
fig.update_traces(marker_color='orange', texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Change in Area (Square Kilometers)',
    xaxis={'tickmode':'array', 'tickvals':year_on_year_change_df['Year']},
    yaxis=dict(title='Change in Area (Square Kilometers)'),
    title_x=0.5
)

# Show the figure
fig.show()

# %%
import plotly.express as px

fig = px.line(area_per_year_sq_km.reset_index(), x='Year', y='Area(HEC)', markers=True, title='Year-wise Area under Cultivation')
fig.update_traces(line=dict(color="RoyalBlue", width=3))
fig.update_layout(xaxis_title='Year', yaxis_title='Area (Square Kilometers)', title_x=0.5)
fig.add_annotation(x=max_year, y=max_area, text="Peak Year", showarrow=True, arrowhead=1)
fig.show()
# Out:
# <div>                            <div id="b18d54ad-e95e-4392-9578-72a290d9c766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b18d54ad-e95e-4392-9578-72a290d9c766")) {                    Plotly.newPlot(                        "b18d54ad-e95e-4392-9578-72a290d9c766",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eArea(HEC)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"RoyalBlue","dash":"solid","width":3},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1821983.5,1681843.3800000001,1651576.4100000001,1654069.23,164
# ...

# %% [markdown]
# ## Yield of years Consolidated

# %%
yearly_aggregates = df.groupby('Year').agg({'Production(Tnt)': 'sum', 'Area(HEC)': 'sum'})
yearly_aggregates['Yield'] = yearly_aggregates['Production(Tnt)'] / yearly_aggregates['Area(HEC)']
yearly_yield = yearly_aggregates.reset_index()

# %%
colors = px.colors.qualitative.Vivid

fig = px.line(yearly_yield, x='Year', y='Yield', markers=True, title='Year-wise Yield',
              color_discrete_sequence=[colors[0]])
fig.update_traces(line=dict(width=3))
fig.update_layout(xaxis_title='Year', yaxis_title='Yield (Tons per Hectare)', title_x=0.5)

# Adding vibrant color to the marker
fig.update_traces(marker=dict(size=10, color=colors[1]))

fig.show()

# %% [markdown]
# ## Yield BY column

# %%
# Sum the 'Yield' column for each 'Year'
yearly_yield_sum = df.groupby('Year')['Yield'].sum().reset_index()
yearly_yield_sum
# Out:
#     Year      Yield
# 0   1997  472446.42
# 1   1998  620130.59
# 2   1999  692459.31
# 3   2000  861843.38
# 4   2001  858081.05
# 5   2002 1081934.00
# 6   2003 1077156.55
# 7   2004 1050380.76
# 8   2005 1218739.54
# 9   2006 1299739.08
# 10  2007 1155877.79
# 11  2008 1431993.36
# 12  2009 1474080.83
# 13  2010 1117507.10
# 14  2011 1577452.78
# 15  2012 1105486.17
# 16  2013 1377137.84
# 17  2014 1473204.69
# 18  2015 1470232.38
# 19  2016 1446492.07
# 20  2017 1487611.69
# 21  2018 1534380.39
# 22  2019 1539621.28

# %%
vibrant_color = px.colors.qualitative.Plotly[3]  # Example: A vibrant color from Plotly's qualitative palette

fig = px.bar(yearly_yield_sum, x='Year', y='Yield', title='Sum of Yearly Yields', 
             text='Yield', color_discrete_sequence=[vibrant_color])
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', 
                  xaxis_title='Year',
                  yaxis_title='Sum of Yields',
                  title_x=0.5)

fig.show()

# %% [markdown]
# ## comparision between both ways

# %%
comparison_df = pd.merge(yearly_yield[['Year', 'Yield']], yearly_yield_sum, on='Year', how='inner')
comparison_df.rename(columns={'Yield_x': 'Yield_Method_1', 'Yield_y': 'Yield_Method_2'}, inplace=True)
comparison_df
# Out:
#     Year  Yield_Method_1  Yield_Method_2
# 0   1997            2.48       472446.42
# 1   1998            3.24       620130.59
# 2   1999            3.52       692459.31
# 3   2000            3.40       861843.38
# 4   2001            3.49       858081.05
# 5   2002            3.43      1081934.00
# 6   2003            3.20      1077156.55
# 7   2004            3.08      1050380.76
# 8   2005            3.47      1218739.54
# 9   2006            3.74      1299739.08
# 10  2007            3.91      1155877.79
# 11  2008            3.54      1431993.36
# 12  2009            3.62      1474080.83
# 13  2010            3.82      1117507.10
# 14  2011            4.14      1577452.78
# 15  2012            3.90      1105486.17
# 16  2013            4.20      1377137.84
# 17  2014            4.28      1473204.69
# 18  2015            3.97      1470232.38
# 19  2016            4.13      1446492.07
# 20  2017            4.52      1487611.69
# 21  2018            4.60      1534380.39
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create a figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add bar chart for Yield_Method_2
fig.add_trace(
    go.Bar(x=comparison_df['Year'], y=comparison_df['Yield_Method_2'], name='Yield Method 2', marker_color='lightseagreen'),
    secondary_y=False,
)

# Add line chart for Yield_Method_1
fig.add_trace(
    go.Scatter(x=comparison_df['Year'], y=comparison_df['Yield_Method_1'], name='Yield Method 1', marker_color='indianred', mode='lines+markers'),
    secondary_y=True,
)

# Add titles and labels
fig.update_layout(
    title_text="Comparison of Yields by Calculation Method Over Time",
    xaxis_title="Year"
)

# Set y-axes titles
fig.update_yaxes(title_text="Yield Method 2", secondary_y=False)
fig.update_yaxes(title_text="Yield Method 1", secondary_y=True)

# Show the figure
fig.show()

# %%
df.head(5)
# Out:
#                          State                  District      Crop  Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2019
# 1  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2019
# 2  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2019
# 3  Andaman and Nicobar Islands                  NICOBARS    Banana  2019
# 4  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN    Banana  2019
#
#        Season  Area(HEC)  Production(Tnt)  Yield
# 0        Rabi     612.50           175.40   0.29
# 1        Rabi    2351.11          5343.05   2.27
# 2        Rabi    1372.19          5070.75   3.70
# 3  Whole Year     932.38           609.06   0.65
# 4  Whole Year     665.12          5904.30   8.88

# %%
df.tail(10)
# Out:
#               State         District   Crop  Year Season  Area(HEC)  \
# 345078  West Bengal          HOOGHLY  Wheat  1997   Rabi    1478.00
# 345079  West Bengal           HOWRAH  Wheat  1997   Rabi     755.00
# 345080  West Bengal       JALPAIGURI  Wheat  1997   Rabi   23335.00
# 345081  West Bengal           MALDAH  Wheat  1997   Rabi   47947.00
# 345082  West Bengal   MEDINIPUR EAST  Wheat  1997   Rabi     450.00
# 345083  West Bengal   MEDINIPUR WEST  Wheat  1997   Rabi   15088.00
# 345084  West Bengal      MURSHIDABAD  Wheat  1997   Rabi  122714.00
# 345085  West Bengal            NADIA  Wheat  1997   Rabi   52176.00
# 345086  West Bengal  PURBA BARDHAMAN  Wheat  1997   Rabi    4041.00
# 345087  West Bengal          PURULIA  Wheat  1997   Rabi    1895.00
#
#         Production(Tnt)  Yield
# 345078          2170.00   1.47
# 345079           630.00   0.83
# 345080         40370.00   1.73
# 345081        123880.00   2.58
# 345082           970.00   2.16
# ...
